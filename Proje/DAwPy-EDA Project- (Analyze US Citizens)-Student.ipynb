# %% [markdown]
# <p style="text-align: center"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read data from file

# %%
df = pd.read_csv("adult_eda.csv")

# %% [markdown]
# # Try to undersstand what the data looks like? What are types of the features? Are there any missing values? Do I need to eliminate some features?

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors           13.0
# 1   50  Self-emp-not-inc   83311  Bachelors           13.0
# 2   38           Private  215646    HS-grad            9.0
# 3   53           Private  234721       11th            7.0
# 4   28           Private  338409  Bachelors           13.0
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   31759.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.082843   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.576172   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num      802
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Look at the value counts of columns that have object datatype and replace '?' like values with 'Unknown' word.

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
df.describe(include=[object])
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      32561     32561               32561           32561        27493
# unique         9        16                   7              15            5
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       22696     10501               14976            4140        13193
#
#          race    sex native-country salary
# count   32561  32561          32561  32561
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    27816  21790          29170  24720

# %%
#look at workclass column here
df.workclass.value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df[df["workclass"]== "?"]
# Out:
#        age workclass  fnlwgt     education  education-num  \
# 27      54         ?  180211  Some-college           10.0
# 61      32         ?  293936       7th-8th            4.0
# 69      25         ?  200681  Some-college           10.0
# 77      67         ?  212759          10th            6.0
# 106     17         ?  304873          10th            6.0
# ...    ...       ...     ...           ...            ...
# 32530   35         ?  320084     Bachelors           13.0
# 32531   30         ?   33811     Bachelors           13.0
# 32539   71         ?  287372     Doctorate            NaN
# 32541   41         ?  202822       HS-grad            9.0
# 32542   72         ?  129912       HS-grad            9.0
#
#               marital-status occupation   relationship                race  \
# 27        Married-civ-spouse          ?        Husband  Asian-Pac-Islander
# 61     Married-spouse-absent          ?  Not-in-family               White
# 69             Never-married          ?            NaN               White
# 77        Married-civ-spouse          ?        Husband               White
# 106            Never-married          ?            NaN               White
# ...                      ...        ...            ...                 ...
# 32530     Married-civ-spouse          ?           Wife               White
# 32531          Never-married          ?  Not-in-family  Asian-Pac-Islander
# 32539     Married-civ-spouse          ?        Husband               White
# 32541              Separated          ?  Not-in-family               Black
# 32542     Married-civ-spouse          ?        Husband               White
#
#           sex  capital-gain  capital-loss  hours-per-week native-country  \
# 27       Male             0             0              60          South
# 61       Male             0             0              40              ?
# 69       Male             0             0              40  United-States
# 77       Male             0             0               2  United-States
# 106    Female         34095             0              32  United-States
# ...       ...           ...           ...             ...            ...
# 32530  Female             0             0              55  United-States
# 32531  Female             0             0              99  United-States
# 32539    Male             0             0              10  United-States
# 32541  Female             0             0              32  United-States
# 32542    Male             0             0              25  United-States
#
#       salary
# 27      >50K
# 61     <=50K
# 69     <=50K
# 77     <=50K
# 106    <=50K
# ...      ...
# 32530   >50K
# 32531  <=50K
# 32539   >50K
# 32541  <=50K
# 32542  <=50K
#
# [1836 rows x 15 columns]

# %%
df[df["workclass"] != "?"]["workclass"].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
#replace all '?' in whole df with 'Unknown'
df = df.replace("?","Unknow")

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors           13.0
# 1       50  Self-emp-not-inc   83311   Bachelors           13.0
# 2       38           Private  215646     HS-grad            9.0
# 3       53           Private  234721        11th            7.0
# 4       28           Private  338409   Bachelors           13.0
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm           12.0
# 32557   40           Private  154374     HS-grad            9.0
# 32558   58           Private  151910     HS-grad            9.0
# 32559   22           Private  201490     HS-grad            9.0
# 32560   52      Self-emp-inc  287927     HS-grad            9.0
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical            NaN  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 15 columns]

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Do education and education_num columns hold similar information? If so drop the appropriate choice between them.

# %%
df.education
# Out:
# 0         Bachelors
# 1         Bachelors
# 2           HS-grad
# 3              11th
# 4         Bachelors
#             ...
# 32556    Assoc-acdm
# 32557       HS-grad
# 32558       HS-grad
# 32559       HS-grad
# 32560       HS-grad
# Name: education, Length: 32561, dtype: object

# %%
df["education-num"]
# Out:
# 0        13.0
# 1        13.0
# 2         9.0
# 3         7.0
# 4        13.0
#          ...
# 32556    12.0
# 32557     9.0
# 32558     9.0
# 32559     9.0
# 32560     9.0
# Name: education-num, Length: 32561, dtype: float64

# %%
df.groupby("education")["education-num"].value_counts()
# Out:
# education     education-num
# 10th          6.0                916
# 11th          7.0               1146
# 12th          8.0                424
# 1st-4th       2.0                161
# 5th-6th       3.0                330
# 7th-8th       4.0                631
# 9th           5.0                503
# Assoc-acdm    12.0              1044
# Assoc-voc     11.0              1343
# Bachelors     13.0              5247
# Doctorate     16.0               405
# HS-grad       9.0              10215
# Masters       14.0              1687
# Preschool     1.0                 50
# Prof-school   15.0               559
# Some-college  10.0              7098
# Name: education-num, dtype: int64

# %%
df["education-num"].value_counts()
# Out:
# 9.0     10215
# 10.0     7098
# 13.0     5247
# 14.0     1687
# 11.0     1343
# 7.0      1146
# 12.0     1044
# 6.0       916
# 4.0       631
# 15.0      559
# 5.0       503
# 8.0       424
# 16.0      405
# 3.0       330
# 2.0       161
# 1.0        50
# Name: education-num, dtype: int64

# %%
#drop one of them here
df = df.drop(["education-num"],axis=1)

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Take a look at correlation between variables and also see if there are some outliers in any of the columns.

# %%
df.corr()
# Out:
#                      age    fnlwgt  capital-gain  capital-loss  hours-per-week
# age             1.000000 -0.076646      0.077674      0.057775        0.068756
# fnlwgt         -0.076646  1.000000      0.000432     -0.010252       -0.018768
# capital-gain    0.077674  0.000432      1.000000     -0.031615        0.078409
# capital-loss    0.057775 -0.010252     -0.031615      1.000000        0.054256
# hours-per-week  0.068756 -0.018768      0.078409      0.054256        1.000000

# %%
df.describe()
# Out:
#                 age        fnlwgt  capital-gain  capital-loss  hours-per-week
# count  32561.000000  3.256100e+04  32561.000000  32561.000000    32561.000000
# mean      38.581647  1.897784e+05   1077.648844     87.303830       40.437456
# std       13.640433  1.055500e+05   7385.292085    402.960219       12.347429
# min       17.000000  1.228500e+04      0.000000      0.000000        1.000000
# 25%       28.000000  1.178270e+05      0.000000      0.000000       40.000000
# 50%       37.000000  1.783560e+05      0.000000      0.000000       40.000000
# 75%       48.000000  2.370510e+05      0.000000      0.000000       45.000000
# max       90.000000  1.484705e+06  99999.000000   4356.000000       99.000000

# %%
np.quantile(df.age,0.25)
# Out:
# 28.0

# %%
#age column
IQR_age = np.quantile(df.age,0.75)-np.quantile(df.age,0.25)
IQR_age
# Out:
# 20.0

# %%
upper_lim_age = np.quantile(df.age,0.75) + 1.5*IQR_age
upper_lim_age
# Out:
# 78.0

# %%
df[df["age"] >= upper_lim_age]["age"].value_counts()
# Out:
# 90    43
# 78    23
# 79    22
# 80    22
# 81    20
# 82    12
# 84    10
# 83     6
# 88     3
# 85     3
# 86     1
# 87     1
# Name: age, dtype: int64

# %%
fig ,ax = plt.subplots(2,3,figsize=(20,7))
x = 0
y = 0
for column in df.select_dtypes('number').columns:
    
    df[column].plot(kind = "box", ax = ax[x,y])
    if y < 2:
        y += 1
    else:
        x += 1
        y = 0

# %%
df[(df["hours-per-week"] == 99)].sample(10)
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 10986   38           Private  111499       HS-grad  Married-civ-spouse
# 27222   32         Local-gov  113838  Some-college  Married-civ-spouse
# 26858   66           Private  262285     Bachelors  Married-civ-spouse
# 13858   37           Private   51264     Doctorate  Married-civ-spouse
# 30754   31           Private   33124   Prof-school       Never-married
# 32531   30            Unknow   33811     Bachelors       Never-married
# 1887    55  Self-emp-not-inc  184425  Some-college  Married-civ-spouse
# 14593   27           Private  179915     Bachelors       Never-married
# 15180   25           Private  356017          11th       Never-married
# 8072    44  Self-emp-not-inc   26669    Assoc-acdm  Married-civ-spouse
#
#             occupation   relationship                race     sex  \
# 10986            Sales        Husband               White    Male
# 27222  Protective-serv        Husband               White    Male
# 26858   Prof-specialty        Husband               White    Male
# 13858   Prof-specialty        Husband               White    Male
# 30754   Prof-specialty  Not-in-family               White  Female
# 32531           Unknow  Not-in-family  Asian-Pac-Islander  Female
# 1887   Farming-fishing        Husband               White    Male
# 14593  Exec-managerial            NaN               White  Female
# 15180    Other-service  Not-in-family               White    Male
# 8072     Other-service           Wife               White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 10986             0          1977              99  United-States   >50K
# 27222             0             0              99  United-States  <=50K
# 26858             0             0              99  United-States  <=50K
# 13858             0             0              99         France   >50K
# 30754             0             0              99  United-States  <=50K
# 32531             0             0              99  United-States  <=50K
# 1887              0             0              99  United-States   >50K
# 14593             0             0              99  United-States  <=50K
# 15180             0             0              99  United-States  <=50K
# 8072              0             0              99  United-States  <=50K

# %%
#hours per week column
IQR_hpw = np.quantile(df["hours-per-week"],0.75)-np.quantile(df["hours-per-week"],0.25)
IQR_hpw
# Out:
# 5.0

# %%
upper_lim_hpw = np.quantile(df["hours-per-week"],0.75) + 1.5*IQR_hpw
upper_lim_hpw
# Out:
# 52.5

# %%
# find outlier values which extends the upper limit in both age and hours-per-week columns

# %%
df.loc[(df["hours-per-week"] > upper_lim_hpw) & (df["age"] > upper_lim_age)]
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 3777    80       Private   87518  Some-college       Never-married
# 5370    90     Local-gov  227796       Masters  Married-civ-spouse
# 7481    83       Private  195507       HS-grad             Widowed
# 7720    84       Private  241065       Masters       Never-married
# 8806    90       Private   87372   Prof-school  Married-civ-spouse
# 11996   90       Private   40388     Bachelors       Never-married
# 12830   81       Private  201398       Masters             Widowed
# 15356   90       Private   90523       HS-grad             Widowed
# 24395   83  Self-emp-inc  153183     Bachelors  Married-civ-spouse
#
#              occupation   relationship   race   sex  capital-gain  \
# 3777     Prof-specialty  Not-in-family  White  Male             0
# 5370    Exec-managerial        Husband  White  Male         20051
# 7481    Protective-serv  Not-in-family  White  Male             0
# 7720     Prof-specialty  Not-in-family  White  Male             0
# 8806     Prof-specialty        Husband  White  Male         20051
# 11996   Exec-managerial  Not-in-family  White  Male             0
# 12830    Prof-specialty      Unmarried  White  Male             0
# 15356  Transport-moving      Unmarried  White  Male             0
# 24395   Exec-managerial        Husband  White  Male             0
#
#        capital-loss  hours-per-week native-country salary
# 3777           1816              60  United-States  <=50K
# 5370              0              60  United-States   >50K
# 7481              0              55  United-States  <=50K
# 7720              0              66  United-States  <=50K
# 8806              0              72  United-States   >50K
# 11996             0              55  United-States  <=50K
# 12830             0              60         Unknow  <=50K
# 15356             0              99  United-States  <=50K
# 24395          2392              55  United-States   >50K

# %% [markdown]
# # After looking at the outliers you can drop the rows which actually does not make any sense.
# ** Hint: You can check age and hours per week columns. **

# %%
drop_index = df.loc[(df["hours-per-week"] >= upper_lim_hpw) & (df["age"] >= upper_lim_age)].index
drop_index
# Out:
# Int64Index([3777, 5370, 7481, 7720, 8806, 10546, 11996, 12830, 15356, 24395], dtype='int64')

# %%
df = df.drop(drop_index)

# %%
# check outlier values which extends the upper limit in both age and hours-per-week columns
df.loc[(df["hours-per-week"] > upper_lim_hpw) & (df["age"] > upper_lim_age)]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %% [markdown]
# # Impute missing values in relationship column with 'Unmarried'. Also replace 'Not-in-family','Other-relative' values in this column with 'Unmarried'?

# %%
df.relationship.value_counts()
# Out:
# Husband           13189
# Not-in-family      8301
# Unmarried          3444
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
df.relationship = df.relationship.str.replace("Not-in-family","Unmarried").str.replace("Other-relative","Unmarried")

# %%
df.relationship.value_counts()
# Out:
# Husband      13189
# Unmarried    12726
# Wife          1568
# Name: relationship, dtype: int64

# %% [markdown]
# ---
# # How many of each race are represented in this dataset?
# ---

# %%
race_count = df.race.value_counts()
race_count
# Out:
# White                 27806
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
race_count.sort_values().plot.barh();

# %% [markdown]
# ---
# # What is the average age of men/women?
# ---

# %%
average_age_men = df[df.sex == "Male"].mean()["age"]
average_age_men
# Out:
# C:\Users\win7\AppData\Local\Temp\ipykernel_1548\534552203.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   average_age_men = df[df.sex == "Male"].mean()["age"]
# 39.41267217630854

# %%
round(average_age_men,1)
# Out:
# 39.4

# %%
plt.figure(figsize = (15,7))
df.loc[df["sex"] == "Male", "age"].value_counts().plot.bar();

# %%
average_age_women = df[df.sex == "Female"].mean()["age"]
average_age_women
# Out:
# C:\Users\win7\AppData\Local\Temp\ipykernel_1548\2181515729.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   average_age_women = df[df.sex == "Female"].mean()["age"]
# 36.85823043357163

# %%
plt.figure(figsize = (15,7))
df.loc[df["sex"] == "Female", "age"].value_counts().plot.bar();

# %% [markdown]
# ---
# # What is the percentage of people who have a Bachelor's degree?
# ---

# %%
df.groupby("education")["education"].count()
# Out:
# education
# 10th              933
# 11th             1175
# 12th              433
# 1st-4th           168
# 5th-6th           333
# 7th-8th           645
# 9th               514
# Assoc-acdm       1067
# Assoc-voc        1382
# Bachelors        5353
# Doctorate         413
# HS-grad         10499
# Masters          1720
# Preschool          51
# Prof-school       575
# Some-college     7290
# Name: education, dtype: int64

# %%
df.education.value_counts()
# Out:
# HS-grad         10499
# Some-college     7290
# Bachelors        5353
# Masters          1720
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       575
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
upper = df[df.education=="Bachelors"]["education"].count()

lower = df.education.count()

percentage_bachelors = upper / lower * 100

percentage_bachelors
# Out:
# 16.444963288378236

# %%
df["education"].value_counts(normalize=True)
# Out:
# HS-grad         0.322540
# Some-college    0.223956
# Bachelors       0.164450
# Masters         0.052840
# Assoc-voc       0.042456
# 11th            0.036097
# Assoc-acdm      0.032779
# 10th            0.028663
# 7th-8th         0.019815
# Prof-school     0.017665
# 9th             0.015791
# 12th            0.013302
# Doctorate       0.012688
# 5th-6th         0.010230
# 1st-4th         0.005161
# Preschool       0.001567
# Name: education, dtype: float64

# %%
percentage_bachelors = df["education"].value_counts(normalize=True).loc["Bachelors"]*100
round(percentage_bachelors,1)
# Out:
# 16.4

# %%
print(f"The percentage of people who have a Bachelor's degree : %{round(percentage_bachelors,1)}")
# Out:
# The percentage of people who have a Bachelor's degree : %16.4

# %% [markdown]
# ---
# # What percentage of people with advanced education (`Bachelors`, `Masters`, or `Doctorate`) make more than 50K?
# ---

# %%
df.salary.value_counts()
# Out:
# <=50K    24713
# >50K      7838
# Name: salary, dtype: int64

# %%
df.education.value_counts()
# Out:
# HS-grad         10499
# Some-college     7290
# Bachelors        5353
# Masters          1720
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       575
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
df.head(10)
# Out:
#    age         workclass  fnlwgt  education         marital-status  \
# 0   39         State-gov   77516  Bachelors          Never-married
# 1   50  Self-emp-not-inc   83311  Bachelors     Married-civ-spouse
# 2   38           Private  215646    HS-grad               Divorced
# 3   53           Private  234721       11th     Married-civ-spouse
# 4   28           Private  338409  Bachelors     Married-civ-spouse
# 5   37           Private  284582    Masters     Married-civ-spouse
# 6   49           Private  160187        9th  Married-spouse-absent
# 7   52  Self-emp-not-inc  209642    HS-grad     Married-civ-spouse
# 8   31           Private   45781    Masters          Never-married
# 9   42           Private  159449  Bachelors     Married-civ-spouse
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 0       Adm-clerical    Unmarried  White    Male          2174             0
# 1    Exec-managerial      Husband  White    Male             0             0
# 2  Handlers-cleaners    Unmarried  White    Male             0             0
# 3  Handlers-cleaners      Husband  Black    Male             0             0
# 4     Prof-specialty         Wife  Black  Female             0             0
# 5    Exec-managerial         Wife  White  Female             0             0
# 6      Other-service    Unmarried  Black  Female             0             0
# 7    Exec-managerial      Husband  White    Male             0             0
# 8     Prof-specialty    Unmarried  White  Female         14084             0
# 9    Exec-managerial      Husband  White    Male          5178             0
#
#    hours-per-week native-country salary
# 0              40  United-States  <=50K
# 1              13  United-States  <=50K
# 2              40  United-States  <=50K
# 3              40  United-States  <=50K
# 4              40           Cuba  <=50K
# 5              40  United-States  <=50K
# 6              16        Jamaica  <=50K
# 7              45  United-States   >50K
# 8              50  United-States   >50K
# 9              40  United-States   >50K

# %%
higher_education = df.education=="Bachelors"
higher_education
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: education, Length: 32551, dtype: bool

# %%
df_high_edu =df[(df.education=="Bachelors") | (df.education=="Masters") | (df.education=="Doctorate")]
df_high_edu
# Out:
#        age         workclass  fnlwgt  education      marital-status  \
# 0       39         State-gov   77516  Bachelors       Never-married
# 1       50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
# 4       28           Private  338409  Bachelors  Married-civ-spouse
# 5       37           Private  284582    Masters  Married-civ-spouse
# 8       31           Private   45781    Masters       Never-married
# ...    ...               ...     ...        ...                 ...
# 32538   38           Private  139180  Bachelors            Divorced
# 32539   71            Unknow  287372  Doctorate  Married-civ-spouse
# 32544   31           Private  199655    Masters            Divorced
# 32553   32           Private  116138    Masters       Never-married
# 32554   53           Private  321865    Masters  Married-civ-spouse
#
#             occupation relationship                race     sex  capital-gain  \
# 0         Adm-clerical    Unmarried               White    Male          2174
# 1      Exec-managerial      Husband               White    Male             0
# 4       Prof-specialty         Wife               Black  Female             0
# 5      Exec-managerial         Wife               White  Female             0
# 8       Prof-specialty    Unmarried               White  Female         14084
# ...                ...          ...                 ...     ...           ...
# 32538   Prof-specialty    Unmarried               Black  Female         15020
# 32539           Unknow      Husband               White    Male             0
# 32544    Other-service    Unmarried               Other  Female             0
# 32553     Tech-support    Unmarried  Asian-Pac-Islander    Male             0
# 32554  Exec-managerial      Husband               White    Male             0
#
#        capital-loss  hours-per-week native-country salary
# 0                 0              40  United-States  <=50K
# 1                 0              13  United-States  <=50K
# 4                 0              40           Cuba  <=50K
# 5                 0              40  United-States  <=50K
# 8                 0              50  United-States   >50K
# ...             ...             ...            ...    ...
# 32538             0              45  United-States   >50K
# 32539             0              10  United-States   >50K
# 32544             0              30  United-States  <=50K
# 32553             0              11         Taiwan  <=50K
# 32554             0              40  United-States   >50K
#
# [7486 rows x 14 columns]

# %%
df[((df.education=="Bachelors") | (df.education=="Masters") | (df.education=="Doctorate")) & (df.salary == ">50K")]
# Out:
#        age         workclass  fnlwgt  education      marital-status  \
# 8       31           Private   45781    Masters       Never-married
# 9       42           Private  159449  Bachelors  Married-civ-spouse
# 11      30         State-gov  141297  Bachelors  Married-civ-spouse
# 19      43  Self-emp-not-inc  292175    Masters            Divorced
# 20      40           Private  193524  Doctorate  Married-civ-spouse
# ...    ...               ...     ...        ...                 ...
# 32533   54           Private  337992  Bachelors  Married-civ-spouse
# 32536   34           Private  160216  Bachelors       Never-married
# 32538   38           Private  139180  Bachelors            Divorced
# 32539   71            Unknow  287372  Doctorate  Married-civ-spouse
# 32554   53           Private  321865    Masters  Married-civ-spouse
#
#             occupation relationship                race     sex  capital-gain  \
# 8       Prof-specialty    Unmarried               White  Female         14084
# 9      Exec-managerial      Husband               White    Male          5178
# 11      Prof-specialty      Husband  Asian-Pac-Islander    Male             0
# 19     Exec-managerial    Unmarried               White  Female             0
# 20      Prof-specialty      Husband               White    Male             0
# ...                ...          ...                 ...     ...           ...
# 32533  Exec-managerial      Husband  Asian-Pac-Islander    Male             0
# 32536  Exec-managerial    Unmarried               White  Female             0
# 32538   Prof-specialty    Unmarried               Black  Female         15020
# 32539           Unknow      Husband               White    Male             0
# 32554  Exec-managerial      Husband               White    Male             0
#
#        capital-loss  hours-per-week native-country salary
# 8                 0              50  United-States   >50K
# 9                 0              40  United-States   >50K
# 11                0              40          India   >50K
# 19                0              45  United-States   >50K
# 20                0              60  United-States   >50K
# ...             ...             ...            ...    ...
# 32533             0              50          Japan   >50K
# 32536             0              55  United-States   >50K
# 32538             0              45  United-States   >50K
# 32539             0              10  United-States   >50K
# 32554             0              40  United-States   >50K
#
# [3484 rows x 14 columns]

# %%
count = df[((df.education=="Bachelors") | (df.education=="Masters") | (df.education=="Doctorate")) & (df.salary == ">50K")]["salary"].count()
count
# Out:
# 3484

# %%
perc_high_edu = count / len(df)

# %%
perc_high_edu
# Out:
# 0.10703204202635863

# %%
print(f"Percentage of people with advanced education make more than 50K : {round(perc_high_edu * 100, 2)}")
# Out:
# Percentage of people with advanced education make more than 50K : 10.7

# %% [markdown]
# ---
# # What percentage of people without advanced education make more than 50K?
# ---

# %%
lower_education = df[~((df.education=="Bachelors") | (df.education=="Masters") | (df.education=="Doctorate"))]["age"].count()
lower_education
# Out:
# 25065

# %%
df_low_edu = df[~((df.education=="Bachelors") | (df.education=="Masters") | (df.education=="Doctorate"))]
df_low_edu
# Out:
#        age         workclass  fnlwgt     education         marital-status  \
# 2       38           Private  215646       HS-grad               Divorced
# 3       53           Private  234721          11th     Married-civ-spouse
# 6       49           Private  160187           9th  Married-spouse-absent
# 7       52  Self-emp-not-inc  209642       HS-grad     Married-civ-spouse
# 10      37           Private  280464  Some-college     Married-civ-spouse
# ...    ...               ...     ...           ...                    ...
# 32556   27           Private  257302    Assoc-acdm     Married-civ-spouse
# 32557   40           Private  154374       HS-grad     Married-civ-spouse
# 32558   58           Private  151910       HS-grad                Widowed
# 32559   22           Private  201490       HS-grad          Never-married
# 32560   52      Self-emp-inc  287927       HS-grad     Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# 2      Handlers-cleaners    Unmarried  White    Male             0
# 3      Handlers-cleaners      Husband  Black    Male             0
# 6          Other-service    Unmarried  Black  Female             0
# 7        Exec-managerial      Husband  White    Male             0
# 10       Exec-managerial      Husband  Black    Male             0
# ...                  ...          ...    ...     ...           ...
# 32556       Tech-support         Wife  White  Female             0
# 32557  Machine-op-inspct      Husband  White    Male             0
# 32558       Adm-clerical    Unmarried  White  Female             0
# 32559       Adm-clerical          NaN  White    Male             0
# 32560    Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country salary
# 2                 0              40  United-States  <=50K
# 3                 0              40  United-States  <=50K
# 6                 0              16        Jamaica  <=50K
# 7                 0              45  United-States   >50K
# 10                0              80  United-States   >50K
# ...             ...             ...            ...    ...
# 32556             0              38  United-States  <=50K
# 32557             0              40  United-States   >50K
# 32558             0              40  United-States  <=50K
# 32559             0              20  United-States  <=50K
# 32560             0              40  United-States   >50K
#
# [25065 rows x 14 columns]

# %%
df[~((df.education=="Bachelors") | (df.education=="Masters") | (df.education=="Doctorate")) & (df.salary == ">50K")]
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 7       52  Self-emp-not-inc  209642       HS-grad  Married-civ-spouse
# 10      37           Private  280464  Some-college  Married-civ-spouse
# 14      40           Private  121772     Assoc-voc  Married-civ-spouse
# 27      54            Unknow  180211  Some-college  Married-civ-spouse
# 38      31           Private   84154  Some-college  Married-civ-spouse
# ...    ...               ...     ...           ...                 ...
# 32518   57         Local-gov  110417       HS-grad  Married-civ-spouse
# 32519   46           Private  364548  Some-college  Married-civ-spouse
# 32545   39         Local-gov  111499    Assoc-acdm  Married-civ-spouse
# 32557   40           Private  154374       HS-grad  Married-civ-spouse
# 32560   52      Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation relationship                race     sex  \
# 7        Exec-managerial      Husband               White    Male
# 10       Exec-managerial      Husband               Black    Male
# 14          Craft-repair      Husband  Asian-Pac-Islander    Male
# 27                Unknow      Husband  Asian-Pac-Islander    Male
# 38                 Sales      Husband               White    Male
# ...                  ...          ...                 ...     ...
# 32518       Craft-repair      Husband               White    Male
# 32519    Exec-managerial      Husband               White    Male
# 32545       Adm-clerical         Wife               White  Female
# 32557  Machine-op-inspct      Husband               White    Male
# 32560    Exec-managerial         Wife               White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 7                 0             0              45  United-States   >50K
# 10                0             0              80  United-States   >50K
# 14                0             0              40         Unknow   >50K
# 27                0             0              60          South   >50K
# 38                0             0              38         Unknow   >50K
# ...             ...           ...             ...            ...    ...
# 32518         99999             0              40  United-States   >50K
# 32519             0             0              48  United-States   >50K
# 32545             0             0              20  United-States   >50K
# 32557             0             0              40  United-States   >50K
# 32560         15024             0              40  United-States   >50K
#
# [4354 rows x 14 columns]

# %%
count = df[~((df.education=="Bachelors") | (df.education=="Masters") | (df.education=="Doctorate")) & (df.salary == ">50K")]["age"].count()

# %%
count
# Out:
# 4354

# %%
perc_low_edu = count / len(df)

# %%
print(f"Percentage of people without advanced education make more than 50K : {round(perc_low_edu * 100 ,2)}")
# Out:
# Percentage of people without advanced education make more than 50K : 13.38

# %%
if perc_high_edu > perc_low_edu :
    print("More education more money!")
else:
    print("Education has no clear effet on salary. You should investigate some other features also.")
# Out:
# Education has no clear effet on salary. You should investigate some other features also.

# %% [markdown]
# ---
# # What percentage of the people who work the minimum number of hours per week have a salary of >50K?
# ---

# %%
df["hours-per-week"].value_counts()
# Out:
# 40    15217
# 50     2819
# 45     1824
# 60     1471
# 35     1297
#       ...
# 82        1
# 92        1
# 87        1
# 74        1
# 94        1
# Name: hours-per-week, Length: 94, dtype: int64

# %%
lazy_riches = df["hours-per-week"] == df["hours-per-week"].min()
lazy_riches
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: hours-per-week, Length: 32551, dtype: bool

# %%
df[(df["hours-per-week"]== df["hours-per-week"].min()) & (df.salary == ">50K")]
# Out:
#        age  workclass  fnlwgt  education      marital-status      occupation  \
# 189     58  State-gov  109567  Doctorate  Married-civ-spouse  Prof-specialty
# 20072   65     Unknow   76043    HS-grad  Married-civ-spouse          Unknow
#
#       relationship   race   sex  capital-gain  capital-loss  hours-per-week  \
# 189        Husband  White  Male             0             0               1
# 20072      Husband  White  Male             0             0               1
#
#       native-country salary
# 189    United-States   >50K
# 20072  United-States   >50K

# %%
num_lazy_riches = df[(df["hours-per-week"]== df["hours-per-week"].min()) & (df.salary == ">50K")]["age"].count()
num_lazy_riches
# Out:
# 2

# %%
num_min_workers = df[df["hours-per-week"]== df["hours-per-week"].min()]["age"].count()
num_min_workers
# Out:
# 20

# %%
print (f"Percentage of the people who work the minimum number of hours per week have a salary of >50K : % {round(num_lazy_riches/num_min_workers*100)}")
# Out:
# Percentage of the people who work the minimum number of hours per week have a salary of >50K : % 10

# %% [markdown]
#  ---
#  # What country has the highest percentage of people that earn >50K?
#  ---

# %%
country_salary_df = df.groupby("native-country")[["salary"]].count()
country_salary_df
# Out:
#                             salary
# native-country
# Cambodia                        19
# Canada                         121
# China                           75
# Columbia                        59
# Cuba                            95
# Dominican-Republic              70
# Ecuador                         28
# El-Salvador                    106
# England                         90
# France                          29
# Germany                        137
# Greece                          29
# Guatemala                       64
# Haiti                           44
# Holand-Netherlands               1
# Honduras                        13
# Hong                            20
# Hungary                         13
# India                          100
# Iran                            43
# Ireland                         24
# Italy                           73
# Jamaica                         81
# Japan                           62
# Laos                            18
# Mexico                         643
# Nicaragua                       34
# Outlying-US(Guam-USVI-etc)      14
# Peru                            31
# Philippines                    198
# Poland                          60
# Portugal                        37
# Puerto-Rico                    114
# Scotland                        12
# South                           80
# Taiwan                          51
# Thailand                        18
# Trinadad&Tobago                 19
# United-States                29161
# Unknow                         582
# Vietnam                         67
# Yugoslavia                      16

# %%
country_salary_df_riches = df[df.salary ==">50K"].groupby("native-country")[["salary"]].count()
country_salary_df_riches
# Out:
#                     salary
# native-country
# Cambodia                 7
# Canada                  39
# China                   20
# Columbia                 2
# Cuba                    25
# Dominican-Republic       2
# Ecuador                  4
# El-Salvador              9
# England                 30
# France                  12
# Germany                 44
# Greece                   8
# Guatemala                3
# Haiti                    4
# Honduras                 1
# Hong                     6
# Hungary                  3
# India                   40
# Iran                    18
# Ireland                  5
# Italy                   25
# Jamaica                 10
# Japan                   24
# Laos                     2
# Mexico                  33
# Nicaragua                2
# Peru                     2
# Philippines             61
# Poland                  12
# Portugal                 4
# Puerto-Rico             12
# Scotland                 3
# South                   16
# Taiwan                  20
# Thailand                 3
# Trinadad&Tobago          2
# United-States         7168
# Unknow                 146
# Vietnam                  5
# Yugoslavia               6

# %%
rich_per_country = df[df.salary ==">50K"].groupby("native-country")[["salary"]].count() / df.groupby("native-country")[["salary"]].count()
rich_per_country
# Out:
#                               salary
# native-country
# Cambodia                    0.368421
# Canada                      0.322314
# China                       0.266667
# Columbia                    0.033898
# Cuba                        0.263158
# Dominican-Republic          0.028571
# Ecuador                     0.142857
# El-Salvador                 0.084906
# England                     0.333333
# France                      0.413793
# Germany                     0.321168
# Greece                      0.275862
# Guatemala                   0.046875
# Haiti                       0.090909
# Holand-Netherlands               NaN
# Honduras                    0.076923
# Hong                        0.300000
# Hungary                     0.230769
# India                       0.400000
# Iran                        0.418605
# Ireland                     0.208333
# Italy                       0.342466
# Jamaica                     0.123457
# Japan                       0.387097
# Laos                        0.111111
# Mexico                      0.051322
# Nicaragua                   0.058824
# Outlying-US(Guam-USVI-etc)       NaN
# Peru                        0.064516
# Philippines                 0.308081
# Poland                      0.200000
# Portugal                    0.108108
# Puerto-Rico                 0.105263
# Scotland                    0.250000
# South                       0.200000
# Taiwan                      0.392157
# Thailand                    0.166667
# Trinadad&Tobago             0.105263
# United-States               0.245808
# Unknow                      0.250859
# Vietnam                     0.074627
# Yugoslavia                  0.375000

# %%
rich_per_country[rich_per_country.salary == rich_per_country.salary.max()]
# Out:
#                   salary
# native-country
# Iran            0.418605

# %%
#use iloc here
rich_per_country.iloc[[rich_per_country.salary.argmax()]]
# Out:
#                   salary
# native-country
# Iran            0.418605

# %%
plt.figure(figsize=(14,7))
df.loc[df["salary"] == ">50K", "native-country"].value_counts().plot(kind="bar");

# %%
plt.figure(figsize=(12,6))
df.loc[((df["native-country"] == "Iran")), "salary"].value_counts().plot.bar();

# %% [markdown]
# ---
# # Identify the most popular occupation for those who earn >50K in India.
# ---

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'salary'],
#       dtype='object')

# %%
top_IN_occupation = df["native-country"] == "India"

top_IN_occupation
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: native-country, Length: 32551, dtype: bool

# %%
df[top_IN_occupation]
# Out:
#        age         workclass  fnlwgt   education         marital-status  \
# 11      30         State-gov  141297   Bachelors     Married-civ-spouse
# 892     28           Private  164170   Assoc-voc     Married-civ-spouse
# 968     48           Private  164966   Bachelors     Married-civ-spouse
# 1029    48      Self-emp-inc  138370     Masters  Married-spouse-absent
# 1095    22  Self-emp-not-inc  361280   Bachelors          Never-married
# ...    ...               ...     ...         ...                    ...
# 30152   48           Private  119471   Doctorate     Married-civ-spouse
# 30833   25           Private  110978  Assoc-acdm     Married-civ-spouse
# 30871   26           Private  160261     Masters          Never-married
# 31327   38         State-gov  125499   Bachelors     Married-civ-spouse
# 31357   23           Private  143003     Masters     Married-civ-spouse
#
#             occupation relationship                race     sex  capital-gain  \
# 11      Prof-specialty      Husband  Asian-Pac-Islander    Male             0
# 892       Adm-clerical         Wife  Asian-Pac-Islander  Female             0
# 968    Exec-managerial      Husband  Asian-Pac-Islander    Male             0
# 1029             Sales    Unmarried  Asian-Pac-Islander    Male             0
# 1095    Prof-specialty          NaN  Asian-Pac-Islander    Male             0
# ...                ...          ...                 ...     ...           ...
# 30152   Prof-specialty      Husband  Asian-Pac-Islander    Male             0
# 30833     Adm-clerical         Wife  Asian-Pac-Islander  Female             0
# 30871   Prof-specialty    Unmarried  Asian-Pac-Islander    Male             0
# 31327   Prof-specialty      Husband  Asian-Pac-Islander    Male          7688
# 31357   Prof-specialty      Husband  Asian-Pac-Islander    Male             0
#
#        capital-loss  hours-per-week native-country salary
# 11                0              40          India   >50K
# 892               0              40          India  <=50K
# 968               0              40          India   >50K
# 1029              0              50          India  <=50K
# 1095              0              20          India  <=50K
# ...             ...             ...            ...    ...
# 30152             0              40          India   >50K
# 30833             0              37          India   >50K
# 30871             0              20          India  <=50K
# 31327             0              60          India   >50K
# 31357          1887              50          India   >50K
#
# [100 rows x 14 columns]

# %%
df[(df["native-country"] == "India") & (df.salary == ">50K")][["occupation"]].value_counts()
# Out:
# occupation
# Prof-specialty      25
# Exec-managerial      8
# Other-service        2
# Tech-support         2
# Adm-clerical         1
# Sales                1
# Transport-moving     1
# dtype: int64

# %%
df[(df["native-country"] == "India") & (df.salary == ">50K")][["occupation"]].value_counts()[:1].index[0][0]
# Out:
# 'Prof-specialty'

# %%
a = df[(df["native-country"] == "India") & (df.salary == ">50K")][["occupation"]].mode().iloc[0,0]
a
# Out:
# 'Prof-specialty'

# %%
print(f"{a} the most popular occupation for those who earn >50K in India.")
# Out:
# Prof-specialty the most popular occupation for those who earn >50K in India.

# %% [markdown]
# ----
# ---
